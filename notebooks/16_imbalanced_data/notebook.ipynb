# %% [markdown]
# # Imbalanced Data
#
# Practice techniques for handling class imbalance: SMOTE, undersampling, cost-sensitive learning

# %%
# WARNING: This dataset is large (~144MB). Download may take a while.
from sklearn.datasets import fetch_openml
data = fetch_openml("creditcard", version=1)

# %% [markdown]
# ## 1. EDA

# %% [markdown]
# ## 2. Preprocessing

# %% [markdown]
# ## 3. From Scratch Implementation

# %% [markdown]
# ## 4. sklearn Comparison

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# ## 6. Key Takeaways
